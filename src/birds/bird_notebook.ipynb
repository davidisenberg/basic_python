# %%
import sys
sys.path.insert(0, 'C:\\Users\\david\\Documents\\python_projects\\basic_python-1\\src')
from birds.tb_utils import *
from birds.ebird import *
from birds.tb_db import *

#create_hotspot_tables()

#get_tb_hotspots("Hoboken", 40.745255,-74.034775)
# df = get_tb_goldens("Hoboken", 40.745255,-74.034775,151)

# df

# df = get_tb_goldens("Hoboken3", 40.745255,-74.034775,151)

# df

df = get_tb_goldens("Porto Alegre", -30.03306 -51.23,151)

# df


# df = get_tb_goldens("Home", 40.745255,-74.034775,151)

# df

# df = get_tb_goldens("Syracause", 43.0889,-76.1545,100)

# df


# df = get_tb_goldens("Denver", 39.7392,-104.9849,100)

# df

# df = get_tb_goldens("Colorado Springs",38.83389,-104.82528,100)

# df


# df = get_tb_goldens("Minneapolis",44.980553,-93.270035,100)

# df

# df = get_tb_goldens("Duluth",46.78,-92.11,100)

# df

# df = get_tb_goldens("Manaus",-3.117034,-60.025780,100)
# df

# df = get_tb_goldens("San Luis Brazil",-2.52972,-44.30278,100)
# df



# df = get_tb_goldens("Glen Spey", 41.478611, -74.813611,75)

# df

# df = get_tb_goldens("Harriman", 41.240475, -74.098900,75)

# df



#df = get_tb_goldens("ScottsdalePhoenix", 33.4949, -111.9217, 5)
#df

#df = get_tb_goldens("Los AngelesCA", 34.0549, -118.2426, 5)

#df

# df = get_tb_goldens("Menlo Park", 37.4530, -122.1817, 50)
# df

# df = get_tb_goldens("Sao Paulo", -23.533773, -46.625290, 100)
# df

#df = get_tb_goldens("Belize Airport", 17.5361, -88.3078, 200)
# #df

# # df = get_tb_goldens("Ecuador Airport",0.2233, -78.5141, 200) 
# # df

# # df = get_tb_goldens("Fort Lauderdale Airport",26.1224, -80.1373, 200)
# # df

# # df = get_tb_goldens("Cleveland Airport",41.4993, -81.6944, 200)
# # df

# df = get_tb_goldens("Austin Airport",30.1941, -97.6711, 150)
# df

# df = get_tb_goldens("Dallas Airport",32.8990, -97.0336, 150)
# df

# df = get_tb_goldens("Atlanta Airport",33.6324, -84.4333, 150)
# df

# df = get_tb_goldens("New York JFK Airport",40.6446, -73.7797, 150)
# df

# df = get_tb_goldens("Cartagena Airport",10.4463, -75.5165, 150)
# df

# df = get_tb_goldens("Bogota Airport",4.7010, -74.1461, 150)
# df

# df = get_tb_goldens("Buenos Aires Airport",-34.603722, -58.381592, 150)
# df

# df = get_tb_goldens("Ghana Airport",5.607005, -0.171879, 150)
# df


# df = get_tb_goldens("Ghana Airport",5.607005, -0.171879, 150)
# df

# df = get_tb_goldens("Mt. Pocono",41.0361141, -75.34556, 150)
# df

# df = get_tb_goldens("Liberia",10.630573, -85.439346, 150)
# df

# df = get_tb_goldens("Tulum",20.214788,  -87.430588, 150)
# df

#df = get_optimized_hotspots("Hoboken", 5)
#df

# df = get_tb_goldens("Dallas",32.7767,  -96.7970, 150)
# df

# df = get_tb_goldens("Fort Myers",26.6409,  -81.8606, 150)
# df

# df = get_tb_goldens("Everglades City",25.8582,  -81.3851, 150)
# df

# df = get_tb_goldens("Tarrytown",41.0762,  -73.8587, 150)
# df

# df = get_tb_goldens("Orlando",28.5384,  -81.3789, 150)
# df

# df = get_tb_goldens("Tribeca",40.7163,  -74.0086, 150)
# df

# df = get_tb_goldens("Peniche",39.3603,  -9.3876, 150)
# df

# df = get_tb_goldens("Big Bend",29.127487,  -103.242538, 150)
# df

# df = get_tb_goldens("Atlantic City",39.36415000,  -74.42306000, 150)
# df

# df = get_tb_goldens("Shenandoah National Park",38.700516,  -78.292694, 100)
# df

# df = get_tb_goldens("Bogota",4.70139,  -74.14694, 100)
# df

# df = get_tb_goldens("Armenia",4.4528,  -75.7680, 100)
# df



# 32.7767° N, 96.7970° W

# df = q("DESCRIBE hotspots")
# df



# df = q("SELECT * FROM information_schema.tables")
# df
# Out:
# getting tbhotspots
# hotspot table exists
# getting ebird hotspots
# ebird hotspots
# Index(['locId', 'locName', 'countryCode', 'subnational1Code',
#        'subnational2Code', 'lat', 'lng', 'latestObsDt', 'numSpeciesAllTime',
#        'loc_name', 'distance_miles', 'duration', 'rank'],
#       dtype='object')
# appending to table
# returning
# getting last two weeks species
# getting ride times
# get ride time or cached: Hoboken3 40.7025698 -74.0493536
# duration in cache is: 0.0
# getting duration from API
# ...

# %%
import sys
sys.path.insert(0, 'C:\\Users\\david\\Documents\\python_projects\\basic_python-1\\src')
from birds.tb_utils import *
from birds.ebird import *
from birds.tb_db import *
# Out:
#                                               locName  numSpeciesAllTime  \
# 0                     Reserva Ecológica Costanera Sur                348
# 1   Reserva Ecológica Ciudad Universitaria - Costa...                277
# 47                            Museo de la Cárcova-UNA                 51
# 16                                  Ceibas--Terraplén                276
# 5                                Reserva Ribera Norte                245
# ..                                                ...                ...
# 42                                           El Chajá                170
# 89                                  La Lucila del Mar                156
# 83   Reserva Ecológica de la Ciudad Universitaria UNL                189
# 63                                San José del Rincón                222
# 82                 Barra do Quaraí--Estrada Pai Passo                204
#
#     distance_miles  numSpeciesTwoWeeks   golden_rank  duration2
# ...

# %%
df
# Out:
#                                                locName  numSpeciesAllTime  \
# 77           Jamaica Bay Wildlife Refuge--South Garden                243
# 15      Richard W. DeKorte Park--Marsh Discovery Trail                216
# 2                              Richard W. DeKorte Park                281
# 84   Jamaica Bay Wildlife Refuge--East Pond, south end                240
# 12                         Jamaica Bay Wildlife Refuge                322
# ..                                                 ...                ...
# 146                                   Fort Totten Park                207
# 72                  Meadowlands IBA--Kearny Marsh East                160
# 63      Jersey City Reservoir #3 & Pershing Field Park                107
# 126  Meadowlands--Richard Kane Natural Area (restri...                159
# 30   Hackensack Meadowlands Conservation and Wildli...                202
#
#      distance_miles  numSpeciesTwoWeeks    golden_rank  duration2
# ...

# %%
import sys
sys.path.insert(0, 'C:\\Users\\david\\Documents\\python_projects\\basic_python-1\\src')
import requests
import pandas as pd
import duckdb
import geocoder 
from geopy.distance import geodesic
from here.here import get_ride_time



pd.set_option('display.max_rows', 100)


api_token = "thhuoviq2hlq" # Replace with your actual API token

#https://api.ebird.org/v2/ref/adjacent/{{regionCode}}

con = duckdb.connect(database='ebird.duckdb')

loc = geocoder.ip('me').latlng
#loc = [37.468319, -122.143936] #palo alto
loc = [40.745255, -74.034775] #hoboken

def q( query: str):
    #con = duckdb.connect(database='ebird.duckdb')
    result = con.execute(query)
    df = result.fetchall()
    df = pd.DataFrame(df, columns=[desc[0] for desc in result.description])

    return df







# def getinfo(loc: str):
#     https://api.ebird.org/v2/ref/hotspot/info/{{locId}}



#get_indigo()
#get_hotspots()

print(f"num species: " + str(get_numspecies_last14(40.702570,-74.049354)))

DEKORTE_LAT = 40.783300
DEKORTE_LON = -74.102517

print(f"num species: " + str(get_numspecies_last14(DEKORTE_LAT,DEKORTE_LON)))

CENTRAL_PARK_LAT = 40.771548
CENTRAL_PARK_LON = -73.972482

print(f"num species: " + str(get_numspecies_last14(CENTRAL_PARK_LAT,CENTRAL_PARK_LON)))


HOBOKEN_LAT = 40.740058
HOBOKEN_LON = -74.025799

print(f"num species: " + str(get_numspecies_last14(HOBOKEN_LAT,HOBOKEN_LON)))


get_num_good_species_last14(CENTRAL_PARK_LAT,CENTRAL_PARK_LON)

# %%
df = q("select * from taxonomy")
df
# Out:
#                               sciName                  comName speciesCode  \
# 0                    Struthio camelus           Common Ostrich     ostric2
# 1              Struthio molybdophanes           Somali Ostrich     ostric3
# 2      Struthio camelus/molybdophanes    Common/Somali Ostrich      y00934
# 3                 Casuarius casuarius       Southern Cassowary     soucas1
# 4                  Casuarius bennetti          Dwarf Cassowary     dwacas1
# ...                               ...                      ...         ...
# 17410            Saltator fuliginosus  Black-throated Grosbeak     bltgro2
# 17411                    Saltator sp.             saltator sp.     saltat1
# 17412                  Thraupidae sp.           Thraupidae sp.     thraup3
# 17413               Passeriformes sp.            passerine sp.     passer1
# 17414                        Aves sp.                 bird sp.       bird1
#
# ...

# %%
def get_num_good_species_last14(lat, lon):
    url = 'https://api.ebird.org/v2/data/obs/geo/recent?back=14&dist=.5&&lat=' + str(lat) + '&lng=' + str(lon)
    headers = {
    "X-eBirdApiToken": api_token
    }

     # Send GET request
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        local_species = response.json()
        local_species_df = pd.json_normalize(local_species)
        return local_species_df
    
    else:
        print("failure")

df = get_num_good_species_last14(CENTRAL_PARK_LAT,CENTRAL_PARK_LON)
df
# Out:
#    speciesCode                                 comName  \
# 0       cangoo                            Canada Goose
# 1       wooduc                               Wood Duck
# 2       norsho                       Northern Shoveler
# 3       gadwal                                 Gadwall
# 4      mallar3                                 Mallard
# 5       ambduc                     American Black Duck
# 6       buffle                              Bufflehead
# 7       hoomer                        Hooded Merganser
# 8       commer                        Common Merganser
# 9       rebmer                  Red-breasted Merganser
# 10      rudduc                              Ruddy Duck
# 11      rocpig                             Rock Pigeon
# 12      moudov                           Mourning Dove
# 13      y00475                           American Coot
# 14      ribgul                        Ring-billed Gull
# 15     amhgul1                   American Herring Gull
# ...

# %%
#df = q("select locName,lat, lng, subnational1Code, numSpeciesAllTime, distance_miles, rank from loc where  (numSpeciesAllTime > 200) or (distance_miles < 2) order by rank desc limit 20")
df = q("select * from loc where  (numSpeciesAllTime > 200) or (distance_miles < 2) order by rank desc limit 20")

df
# Out:
#         locId                                            locName countryCode  \
# 0     L211437                    Stevens Institute of Technology          US
# 1    L1392119                   Hudson River Park--22nd-29th St.          US
# 2     L189035                                         Liberty SP          US
# 3    L1166504  Hudson River Park--Greenwich Village (W Housto...          US
# 4    L3246161                                      Hamilton Park          US
# 5   L17144832                                   Hoboken - Pier C          US
# 6     L191106                                       Central Park          US
# 7    L2617135  Hudson River Park--Tribeca Upland (Chambers to...          US
# 8   L10813365     Jersey City Reservoir #3 & Pershing Field Park          US
# 9    L3044567  Hudson River Park--Pier 55 (Little Island, W 1...          US
# 10    L189040                                  Lincoln Park West          US
# ...

# %%
dfa = df[0:100]
dfa['duration'] = dfa.apply(lambda row: get_ride_time(row['lat'], row['lng'], str(loc[0]), str(loc[1])), axis=1)
dfa
# Out:
# {'routes': [{'id': '3adf6989-52b6-449d-afc8-f443b7c1fbbb', 'sections': [{'id': 'fd26a475-7fad-4887-ad44-91d8e9a53294', 'type': 'vehicle', 'departure': {'time': '2024-10-05T21:04:41-04:00', 'place': {'type': 'place', 'location': {'lat': 40.7021783, 'lng': -74.0492003}, 'originalLocation': {'lat': 40.7025697, 'lng': -74.0493537}}}, 'arrival': {'time': '2024-10-05T21:28:50-04:00', 'place': {'type': 'place', 'location': {'lat': 40.7451682, 'lng': -74.0343186}, 'originalLocation': {'lat': 40.7452549, 'lng': -74.034775}}}, 'summary': {'duration': 1449, 'length': 8172, 'baseDuration': 1238}, 'transport': {'mode': 'taxi'}}]}]}
# Duration: 1449 seconds
# Duration: 24 minutes 9 seconds
# ...

# %%
dfa['duration_mins'] = dfa['duration'] / 60
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_12244\155877058.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfa['duration_mins'] = dfa['duration'] / 60

# %%
dfa
# Out:
#                                               locName        lat        lng  \
# 0                                          Liberty SP  40.702570 -74.049354
# 1                                        Central Park  40.771548 -73.972482
# 2                                   Lincoln Park West  40.726410 -74.090546
# 3                   Meadowlands IBA--Mill Creek Marsh  40.795935 -74.049847
# 4                             Richard W. DeKorte Park  40.783300 -74.102517
# 5                      Governors Island (N.Y. County)  40.688537 -74.018976
# 6                            Central Park--The Ramble  40.777967 -73.969717
# 7                                Brooklyn Bridge Park  40.699610 -73.997375
# 8      Richard W. DeKorte Park--Marsh Discovery Trail  40.785376 -74.100513
# 9   Meadowlands IBA--Harrier Meadows (restricted a...  40.787983 -74.118919
# 10                      Meadowlands IBA--Kearny Marsh  40.760221 -74.132692
# ...

# %%
q("select locName, count(*) from obs group by locName having count(*) > 3")
# Out:
#                                               locName  count_star()
# 0                                                Home             6
# 1                              Commerce Road Wetlands            12
# 2             Salt Marsh Nature Center at Marine Park             8
# 3                               Sandy Hook--North End             6
# 4                                          Sandy Hook             5
# 5                                 Hilltop Reservation             6
# 6                                       Prospect Park             9
# 7                             Bay Ridge - 86th Street             7
# 8                                          Cooper Rd.             5
# 9   Jamaica Bay Wildlife Refuge--East Pond, south end            11
# 10                                 Ramapo Mountain SF             4
# 11  Jamaica Bay Wildlife Refuge--East Pond, north end             7
# 12                  Sandy Hook--Platform & North Pond             4
# ...

# %%
q("select count(*) from obs")
# Out:
# [(185,)]

# %%
import sys



print(sys.path)
# Out:
# hello
# {'routes': [{'id': '92ab92a8-df1b-42e3-82df-da16daf270f3', 'sections': [{'id': '237f2094-8910-422a-8d91-31b1c3db9d79', 'type': 'vehicle', 'departure': {'time': '2024-10-05T20:35:32-04:00', 'place': {'type': 'place', 'location': {'lat': 40.7451682, 'lng': -74.0343186}, 'originalLocation': {'lat': 40.7452549, 'lng': -74.034775}}}, 'arrival': {'time': '2024-10-05T20:58:10-04:00', 'place': {'type': 'place', 'location': {'lat': 40.7021782, 'lng': -74.0492005}, 'originalLocation': {'lat': 40.70257, 'lng': -74.049354}}}, 'summary': {'duration': 1358, 'length': 6897, 'baseDuration': 1064}, 'transport': {'mode': 'taxi'}}]}]}
# Duration: 1358 seconds
# Duration: 22 minutes 38 seconds
# 1358
# ...

# %%
# Out:
# ['../src', '../src', 'C:\\Users\\david\\AppData\\Local\\Programs\\Python\\Python310', 'c:\\Users\\david\\AppData\\Local\\Programs\\Python\\Python310\\python310.zip', 'c:\\Users\\david\\AppData\\Local\\Programs\\Python\\Python310\\DLLs', 'c:\\Users\\david\\AppData\\Local\\Programs\\Python\\Python310\\lib', '', 'C:\\Users\\david\\AppData\\Roaming\\Python\\Python310\\site-packages', 'C:\\Users\\david\\AppData\\Roaming\\Python\\Python310\\site-packages\\win32', 'C:\\Users\\david\\AppData\\Roaming\\Python\\Python310\\site-packages\\win32\\lib', 'C:\\Users\\david\\AppData\\Roaming\\Python\\Python310\\site-packages\\Pythonwin', 'c:\\Users\\david\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages']
